# %% [markdown]
# # setup

# %%
import os, sys, json, math, random
from dataclasses import asdict

import numpy as np
import pandas as pd
import torch
from torch.utils.data import DataLoader, Subset
from torch.optim import AdamW
from torch.cuda.amp import GradScaler

# --- project root & local modules ---
PROJ_ROOT = "/home/hernan_melmoth/Documents/phd_work/otu-taxa-foundation"
sys.path.append(os.path.join(PROJ_ROOT, "src"))

from otu_taxa.helpers_pretraining_model import MetricsLogger, set_seed, save_checkpoint, IGNORE_INDEX
from otu_taxa.trainer_hier_joint_unk import run_epoch

from otu_taxa.joint_hier_loss_metrics_unk import make_factorized_tax_loss_fn_fast_masked_with_unk
from otu_taxa.otu_taxa_transformer_unk import ModelConfig, OTUTaxaTransformerEmbedTaxTreeUnkTaxa
from otu_taxa.dataloaders_unk_balance_ranks import (
    OTUTaxaDataset,
    MaskingConfig,
    make_collator_balanced_rank,
    build_tax2ancestor_at_ranks,
)

# %% [markdown]
# # data

# %%
# -----------------------------------
# Paths & config (single source of truth)
# -----------------------------------
PROJ_ROOT = "/home/hernan_melmoth/Documents/phd_work/otu-taxa-foundation"

# External (heavy) dataset location (outside repo)
DATASET_ROOT = "/home/hernan_melmoth/Documents/phd_work/Microbeatlas_preprocess_training"
dataset_folder_name = "dataset_full_top999"   # <- adjust if you used a different name
dataset_dir = os.path.join(
    DATASET_ROOT,
    "level_97",
    "silva-138.2",
    "incomplete_silva_sintax",
    dataset_folder_name,
)

# Base dataset artifacts
TAXONOMY_VOCAB_PATH = os.path.join(dataset_dir, "taxonomy_vocab.json")
path_to_taxonomy_tree = os.path.join(dataset_dir, "taxonomy_nested.json")
SAMPLES_JSONL = os.path.join(dataset_dir, "samples.jsonl")

# Tree artifacts directory (derived)
TREE_DIR = os.path.join(dataset_dir, "tree_artifacts")

# LCA (prefer .npy in new pipeline; keep CSV fallback if you still have it)
LCA_NPY = os.path.join(TREE_DIR, "lca_distance_edges.npy")
LCA_CSV = os.path.join(TREE_DIR, "lca_distance_edges.csv")  # optional legacy

# Descendant matrices
DESCENDANT_MATRIX_PATH = os.path.join(TREE_DIR, "descendant_matrix.npy")              # real tree only
UNK_VOCAB_PATH         = os.path.join(TREE_DIR, "taxonomy_vocab_with_unk.json")       # real + 7 UNKs
UNK_M_PATH             = os.path.join(TREE_DIR, "descendant_matrix_with_unk.npy")     # real+UNK closure
RANK_IDX_PATH          = os.path.join(TREE_DIR, "rank_idx.npy")                       # rank per token (0..6)

# # Optional: test split ids (only if you created it for the full corpus)
# TEST_IDS_PATH = os.path.join(dataset_dir, "splits", "test_samples_2000.txt")  # adjust if needed

# Run / output dir (inside repo)
run_name = "pretrain_hier_joint_unk_taxa_balanced_ranks"
out_dir = os.path.join(PROJ_ROOT, "runs_microbeatlas", run_name)
os.makedirs(out_dir, exist_ok=True)

# -----------------------------------
# Load LCA distance matrix
# -----------------------------------
if os.path.exists(LCA_NPY):
    D_tree = torch.from_numpy(np.load(LCA_NPY)).float()
else:
    df_D = pd.read_csv(LCA_CSV, index_col=0)
    D_tree = torch.tensor(df_D.values, dtype=torch.float32)

print("LCA distance matrix:", D_tree.shape)

# save logs
metrics_path = os.path.join(out_dir, "metrics.jsonl")
logger = MetricsLogger(metrics_path)

# -----------------------------------
# Taxonomy sizes: T_real vs T_base
# -----------------------------------
# ORIGINAL vocab (no UNKs), for tree regularizer and T_real
with open(TAXONOMY_VOCAB_PATH, "r") as f:
    tax_vocab_real = json.load(f)
T_real = len(tax_vocab_real)
print("T_real (original taxa, just k UNK):", T_real)

# UNK-extended vocab & descendant matrix for hierarchical loss
with open(UNK_VOCAB_PATH, "r") as f:
    tax_vocab_unk = json.load(f)
T_base = len(tax_vocab_unk)
print("T_base (real + UNK):", T_base)

# Load UNK-extended descendant matrix (used by hierarchical loss)
D_np_unk = np.load(UNK_M_PATH)          # [T_base, T_base]
M_tensor = torch.from_numpy(D_np_unk)   # keep name M_tensor for the loss
print("Descendant matrix with UNK:", M_tensor.shape)

# Optional: real-only descendant matrix (if needed for debugging)
D_np_real = np.load(DESCENDANT_MATRIX_PATH)        # [T_real, T_real]
descendant_matrix_real = torch.from_numpy(D_np_real)
print("Descendant matrix (real only):", descendant_matrix_real.shape)

# Optional: rank_idx (often used by loss/metrics/collator)
rank_idx = np.load(RANK_IDX_PATH)  # shape [T_base]
print("rank_idx:", rank_idx.shape)
# Out:
# LCA distance matrix: torch.Size([6929, 6929])
# T_real (original taxa, just k UNK): 6929
# T_base (real + UNK): 6935
# Descendant matrix with UNK: torch.Size([6935, 6935])
# Descendant matrix (real only): torch.Size([6929, 6929])
# rank_idx: (6935,)

# %%
# import json
# import numpy as np
# from tqdm import tqdm

# def compute_length_percentiles(samples_jsonl_path, percentiles=(50, 75, 90, 95, 99, 99.9)):
#     lengths = []
#     with open(samples_jsonl_path, "r") as f:
#         for line in tqdm(f, desc="Reading sample lengths"):
#             if not line.strip():
#                 continue
#             rec = json.loads(line)
#             lengths.append(len(rec["otus"]))
#     lengths = np.asarray(lengths, dtype=np.int32)

#     out = {p: int(np.percentile(lengths, p)) for p in percentiles}
#     return out, lengths

# pct, lengths = compute_length_percentiles(SAMPLES_JSONL, percentiles=(90, 95, 99))
# print("Length percentiles:", pct)
# print("Max length:", int(lengths.max()))

# %%
# -----------------------------------
# Training hyperparameters
# (experiment-specific configuration)
# -----------------------------------
seed = 123
device = "cuda" if torch.cuda.is_available() else "cpu"

epochs = 24
train_batch_size = int(32 * 2)
val_batch_size   = 64

max_len = 500                    # 96th percentile sequence length
mlm_prob = 0.15                  # masking rate
prob_joint, prob_otu_only, prob_tax_only = 0.50, 0.25, 0.25
keep_prob, random_prob = 0.10, 0.10

balance_rank_prob = 0.3 


lr = 1e-3
weight_decay = 1e-3
warmup_ratio = 0.06
max_grad_norm = 1.0
grad_accum_steps = 2

TREE_LAMBDA = 10                 # tree regularization weight
num_workers = 0                  # 0 for determinism

# %%
# -----------------------------------
# Dataset & random split (20k TEST, 10k VAL, rest TRAIN)
# -----------------------------------
set_seed(seed)
random.seed(seed)

# 1) Load full dataset once
ds = OTUTaxaDataset(dataset_dir)
N = len(ds)
print(f"[INFO] Dataset size: N={N}")

# 2) Choose split sizes (cap if dataset is smaller)
TEST_N = min(20_000, N)
VAL_N  = min(20_000, N - TEST_N)

# 3) Random permutation of indices
all_idx = list(range(N))
random.shuffle(all_idx)

test_idx  = sorted(all_idx[:TEST_N])
val_idx   = sorted(all_idx[TEST_N:TEST_N + VAL_N])
train_idx = sorted(all_idx[TEST_N + VAL_N:])

print(f"[SPLIT] Train={len(train_idx)}  Val={len(val_idx)}  Test={len(test_idx)}  (Total N={N})")

# 4) Subsets
train_ds = Subset(ds, train_idx)
val_ds   = Subset(ds, val_idx)
test_ds  = Subset(ds, test_idx)
# Out:
# [INFO] Dataset size: N=1836250
# [SPLIT] Train=1796250  Val=20000  Test=20000  (Total N=1836250)

# %%
# ------------------------------------------------------------
# Build tax2fam ONCE (do this earlier in the notebook)
# ------------------------------------------------------------

with open(UNK_VOCAB_PATH, "r", encoding="utf-8") as f:
    tax_vocab_with_unk = json.load(f)

M_np = np.load(UNK_M_PATH)  # [T_base, T_base] ancestor->descendant

### collator balanced per family + OTUs:
tax2anc_by_rank = build_tax2ancestor_at_ranks(M_np, tax_vocab_with_unk)  # dict rank->list[int]

# %%
# -----------------------------------
# Collators & loaders
# -----------------------------------

# TRAIN collator: stochastic masking + BOTH balancing strategies
train_cfg = MaskingConfig(
    mlm_prob=mlm_prob,
    prob_joint=prob_joint,
    prob_otu_only=prob_otu_only,
    prob_tax_only=prob_tax_only,
    max_len=max_len,
    keep_prob=keep_prob,
    random_prob=random_prob,

    #### collator balanced per rank + OTUs:
    balance_mode="random" ,        
    balance_rank_prob =  balance_rank_prob,     # only if balance_mode="random"
)

train_collate = make_collator_balanced_rank(
    dataset=ds,
    cfg=train_cfg,
    tax2anc_by_rank=tax2anc_by_rank,)

# VAL / TEST collator:
# Recommended: keep masking same, but DISABLE balancing (so evaluation is not distribution-shaped).
val_cfg = MaskingConfig(
    mlm_prob=mlm_prob,
    prob_joint=prob_joint,
    prob_otu_only=prob_otu_only,
    prob_tax_only=prob_tax_only,
    max_len=max_len,
    keep_prob=keep_prob,
    random_prob=random_prob,
    balance_mode="none",    # important: no endpoint re-selection for eval
)

val_collate = make_collator_balanced_rank(
    dataset=ds,
    cfg=val_cfg,
    tax2anc_by_rank=tax2anc_by_rank,)

test_collate = make_collator_balanced_rank(
    dataset=ds,
    cfg=val_cfg,
    tax2anc_by_rank=tax2anc_by_rank,)

# DataLoaders

train_loader = DataLoader(
    train_ds,
    batch_size=train_batch_size,
    shuffle=True,
    collate_fn=train_collate,
    num_workers=num_workers,
    pin_memory=True,
)

val_loader = DataLoader(
    val_ds,
    batch_size=val_batch_size,
    shuffle=False,
    collate_fn=val_collate,
    num_workers=0,
    pin_memory=True,
)

test_loader = DataLoader(
    test_ds,
    batch_size=val_batch_size,
    shuffle=False,
    collate_fn=test_collate,
    num_workers=0,
    pin_memory=True,
)
# -----------------------------------
# Model sizes & PAD ids (single place)
# -----------------------------------

# OTUs: unchanged
n_otus = ds.O + 2            # + pad, mask
pad_otu_id = ds.O

# TAXA (UNK-aware):
# - T_real = original number of taxa (from taxonomy_vocab.json)
# - T_base = len(tax_vocab_unk) = T_real + 7 (real + UNKs)
# - n_taxa = T_base + 2 (PAD, MASK at the end)
n_taxa = T_base + 2
pad_tax_id  = T_base         # PAD token index
mask_tax_id = T_base + 1     # MASK token index

# %% [markdown]
# # Load model

# %%
# -----------------------------
# Build model config
# -----------------------------
model_cfg = ModelConfig(
    d_model=256, n_layers=6, n_heads=4, d_ff=1024,
    dropout=0.1, activation="gelu",
    tie_otu_weights=True,
    otu_loss_weight=1.0,
    tax_loss_weight=1.0,
    #lambda_tree=TREE_LAMBDA,
    emb_dropout=0.1,
    layernorm_emb=True,
    #lca_csv=LCA_CSV,          # LCA over ORIGINAL taxonomy (T_real x T_real)
    T_real=T_real,            # <- NEW: number of original taxa for tree regularizer
)

# -----------------------------
# Hierarchical taxonomy loss (UNK-aware)
# -----------------------------
# Here we use the UNK-extended vocab and M_tensor that we loaded earlier:
#   - tax_vocab_unk: list[str], len = T_base = T_real + 7
#   - M_tensor: [T_base, T_base] descendant-closure with UNKs

def build_rank_idx_from_vocab(vocab_list):
    """
    Returns a LongTensor [len(vocab_list)] with rank indices 0..6 for k..s.
    Assumes tokens start with 'k:', 'p:', ..., 's:' (including UNK ones).
    """
    rank_map = {'k': 0, 'p': 1, 'c': 2, 'o': 3, 'f': 4, 'g': 5, 's': 6}
    out = []
    for name in vocab_list:
        ch = name[0].lower()
        out.append(rank_map.get(ch, -1))
    return torch.tensor(out, dtype=torch.long)

rank_idx = build_rank_idx_from_vocab(tax_vocab_unk)   # [T_base]

# build the UNK-aware hierarchical loss callable
hier_tax_loss_fn = make_factorized_tax_loss_fn_fast_masked_with_unk(
    M_tensor=M_tensor,          # [T_base, T_base] with UNKs
    rank_idx=rank_idx,          # [T_base]
    tax_vocab=tax_vocab_unk,    # len = T_base
    T_base=T_base,              # real + 7 UNKs
)

# -----------------------------
# Init model (UNK-aware)
# -----------------------------
model = OTUTaxaTransformerEmbedTaxTreeUnkTaxa(
    n_otus=n_otus,
    n_taxa=n_taxa,              # = T_base + 2 (PAD, MASK)
    pad_otu_id=pad_otu_id,
    pad_tax_id=pad_tax_id,
    config=model_cfg,
    tax_loss_fn=hier_tax_loss_fn,
).to(device)

# -----------------------------
# Optimizer & Scheduler
# -----------------------------
optimizer = AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)

steps_per_epoch = math.ceil(len(train_loader) / max(1, grad_accum_steps))
total_steps = steps_per_epoch * epochs
warmup_steps = max(1, int(warmup_ratio * total_steps))

def lr_lambda(current_step):
    if current_step < warmup_steps:
        return float(current_step) / float(max(1, warmup_steps))
    return max(0.0, float(total_steps - current_step) / float(max(1, total_steps - warmup_steps)))

scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda)

# AMP scaler
scaler = GradScaler(enabled=(device == "cuda"))

# -----------------------------
# Save run config
# -----------------------------
run_meta = {
    "seed": seed,
    "epochs": epochs,
    "train_batch_size": train_batch_size,
    "val_batch_size": val_batch_size,
    "max_len": max_len,
    "mlm_prob": mlm_prob,
    "prob_split": [prob_joint, prob_otu_only, prob_tax_only],
    "optimizer": {"lr": lr, "weight_decay": weight_decay},
    "sched": {
        "warmup_ratio": warmup_ratio,
        "total_steps": total_steps,
        "warmup_steps": warmup_steps,
    },
    "model_cfg": asdict(model_cfg),
    "dataset": {
        "N": N,
        "N_train": len(train_ds),
        "N_val": len(val_ds),
        "O": ds.O,
        # Keep both for clarity
        "T_real": T_real,       # original taxa (no UNK)
        "T_base": T_base,       # real + UNK (used by loss)
    },
}
with open(os.path.join(out_dir, "meta.json"), "w") as f:
    json.dump(run_meta, f, indent=2)

print(
    f"[INFO] Train={len(train_ds)}  Val={len(val_ds)}  "
    f"Steps/epoch={steps_per_epoch}  Total steps={total_steps}"
)
# Out:
# UNK ids per rank: [6928, 6929, 6930, 6931, 6932, 6933, 6934]
# /home/hernan_melmoth/anaconda3/envs/bio_ontology_env/lib/python3.9/site-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# [INFO] Train=1796250  Val=20000  Steps/epoch=14034  Total steps=336816

# %% [markdown]
# # training model

# %%
rank_map = {'k':0, 'p':1, 'c':2, 'o':3, 'f':4, 'g':5, 's':6}
unk_ids_by_rank = {}

for idx, token in enumerate(tax_vocab_unk):
    # Expect tokens like "k:UNK", "p:UNK", ..., "s:UNK"
    # Adjust this condition if your naming is slightly different.
    if token.endswith("UNK") or token.endswith("unk"):
        prefix = token.split(":")[0]  # 'k','p',...,'s'
        if prefix in rank_map:
            r = rank_map[prefix]
            unk_ids_by_rank[r] = idx

print("UNK IDs per rank:", unk_ids_by_rank)
print("T_base:", T_base)
# Out:
# UNK IDs per rank: {0: 6928, 1: 6929, 2: 6930, 3: 6931, 4: 6932, 5: 6933, 6: 6934}
# T_base: 6935

# %%
best_val = float("inf")
global_step = 0

for epoch in range(1, epochs + 1):

    # ---- TRAIN ----
    train_stats, global_step = run_epoch(
        model=model,
        dataloader=train_loader,
        device=device,
        IGNORE_INDEX=IGNORE_INDEX,
        split="train",
        epoch=epoch,
        global_step=global_step,
        M_tensor=M_tensor,
        rank_idx=rank_idx,
        T_base=T_base,
        optimizer=optimizer,
        scheduler=scheduler,
        scaler=scaler,
        grad_accum_steps=grad_accum_steps,
        max_grad_norm=max_grad_norm,
        logger=logger,
        deterministic_masks=False,

        # NEW controls (UPDATED)
        metric_every_steps=1000,            # log train_step every 1000 optimizer steps
        train_metric_max_positions=2000,    # cap metric compute on probe batches
        progress_every_steps=50,
    )

    # ---- VALIDATION ----
    val_stats, _ = run_epoch(
        model=model,
        dataloader=val_loader,
        device=device,
        IGNORE_INDEX=IGNORE_INDEX,
        split="val",
        epoch=epoch,
        global_step=global_step,
        M_tensor=M_tensor,
        rank_idx=rank_idx,
        T_base=T_base,
        optimizer=None,
        scheduler=None,
        scaler=None,
        grad_accum_steps=1,
        max_grad_norm=max_grad_norm,
        logger=logger,
        deterministic_masks=True,

        # OPTIONAL: evaluate only a subset if val is huge
        # max_eval_batches=200,   # uncomment if needed

        progress_every_steps=0,
    )

    # save best checkpoint (still using val loss as criterion)
    if val_stats["loss"] < best_val:
        best_val = val_stats["loss"]
        save_checkpoint(
            os.path.join(out_dir, "best.pt"),
            model, optimizer, scheduler, scaler,
            epoch, global_step, best_val,
        )
        print(f"[E{epoch:02d}] ✅ Saved BEST")

# FINAL CHECKPOINT
save_checkpoint(
    os.path.join(out_dir, "last.pt"),
    model, optimizer, scheduler, scaler,
    epoch, global_step, best_val,
)
# Out:
# [OTUTaxaTransformerEmbedTaxTree] using otu_loss_fn=default_otu_loss_fn (id=132211155697376) kwargs=['attention_mask', 'ignore_index']
# [OTUTaxaTransformerEmbedTaxTree] using tax_loss_fn=loss_fn (id=132211154521968) kwargs=['ignore_index']
# [OTUTaxaTransformerEmbedTaxTree] using combine_loss_fn=default_combine_loss_fn (id=132211155697088) kwargs=[]
# /home/hernan_melmoth/anaconda3/envs/bio_ontology_env/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:143: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# [E01] TRAIN global_step=50 batch=100
# [E01] TRAIN global_step=100 batch=200
# [E01] TRAIN global_step=150 batch=300
# [E01] TRAIN global_step=200 batch=400
# [E01] TRAIN global_step=250 batch=500
# [E01] TRAIN global_step=300 batch=600
# [E01] TRAIN global_step=350 batch=700
# [E01] TRAIN global_step=400 batch=800
# [E01] TRAIN global_step=450 batch=900
# [E01] TRAIN global_step=500 batch=1000
# [E01] TRAIN global_step=550 batch=1100
# [E01] TRAIN global_step=600 batch=1200
# [E01] TRAIN global_step=650 batch=1300
# [E01] TRAIN global_step=700 batch=1400
# [E01] TRAIN global_step=750 batch=1500
# [E01] TRAIN global_step=800 batch=1600
# [E01] TRAIN global_step=850 batch=1700
# [E01] TRAIN global_step=900 batch=1800
# [E01] TRAIN global_step=950 batch=1900
# [E01] TRAIN global_step=1000 batch=2000
# [E01] TRAIN global_step=1050 batch=2100
# [E01] TRAIN global_step=1100 batch=2200
# [E01] TRAIN global_step=1150 batch=2300
# [E01] TRAIN global_step=1200 batch=2400
# [E01] TRAIN global_step=1250 batch=2500
# [E01] TRAIN global_step=1300 batch=2600
# [E01] TRAIN global_step=1350 batch=2700
# [E01] TRAIN global_step=1400 batch=2800
# [E01] TRAIN global_step=1450 batch=2900
# [E01] TRAIN global_step=1500 batch=3000
# [E01] TRAIN global_step=1550 batch=3100
# [E01] TRAIN global_step=1600 batch=3200
# [E01] TRAIN global_step=1650 batch=3300
# [E01] TRAIN global_step=1700 batch=3400
# [E01] TRAIN global_step=1750 batch=3500
# [E01] TRAIN global_step=1800 batch=3600
# [E01] TRAIN global_step=1850 batch=3700
# [E01] TRAIN global_step=1900 batch=3800
# [E01] TRAIN global_step=1950 batch=3900
# [E01] TRAIN global_step=2000 batch=4000
# [E01] TRAIN global_step=2050 batch=4100
# [E01] TRAIN global_step=2100 batch=4200
# [E01] TRAIN global_step=2150 batch=4300
# [E01] TRAIN global_step=2200 batch=4400
# [E01] TRAIN global_step=2250 batch=4500
# [E01] TRAIN global_step=2300 batch=4600
# [E01] TRAIN global_step=2350 batch=4700
# [E01] TRAIN global_step=2400 batch=4800
# [E01] TRAIN global_step=2450 batch=4900
# [E01] TRAIN global_step=2500 batch=5000
# [E01] TRAIN global_step=2550 batch=5100
# [E01] TRAIN global_step=2600 batch=5200
# [E01] TRAIN global_step=2650 batch=5300
# [E01] TRAIN global_step=2700 batch=5400
# [E01] TRAIN global_step=2750 batch=5500
# [E01] TRAIN global_step=2800 batch=5600
# [E01] TRAIN global_step=2850 batch=5700
# [E01] TRAIN global_step=2900 batch=5800
# [E01] TRAIN global_step=2950 batch=5900
# [E01] TRAIN global_step=3000 batch=6000
# [E01] TRAIN global_step=3050 batch=6100
# [E01] TRAIN global_step=3100 batch=6200
# [E01] TRAIN global_step=3150 batch=6300
# [E01] TRAIN global_step=3200 batch=6400
# [E01] TRAIN global_step=3250 batch=6500
# [E01] TRAIN global_step=3300 batch=6600
# [E01] TRAIN global_step=3350 batch=6700
# [E01] TRAIN global_step=3400 batch=6800
# [E01] TRAIN global_step=3450 batch=6900
# [E01] TRAIN global_step=3500 batch=7000
# [E01] TRAIN global_step=3550 batch=7100
# [E01] TRAIN global_step=3600 batch=7200
# [E01] TRAIN global_step=3650 batch=7300
# [E01] TRAIN global_step=3700 batch=7400
# [E01] TRAIN global_step=3750 batch=7500
# [E01] TRAIN global_step=3800 batch=7600
# [E01] TRAIN global_step=3850 batch=7700
# [E01] TRAIN global_step=3900 batch=7800
# [E01] TRAIN global_step=3950 batch=7900
# [E01] TRAIN global_step=4000 batch=8000
# [E01] TRAIN global_step=4050 batch=8100
# [E01] TRAIN global_step=4100 batch=8200
# [E01] TRAIN global_step=4150 batch=8300
# [E01] TRAIN global_step=4200 batch=8400
# [E01] TRAIN global_step=4250 batch=8500
# [E01] TRAIN global_step=4300 batch=8600
# [E01] TRAIN global_step=4350 batch=8700
# [E01] TRAIN global_step=4400 batch=8800
# [E01] TRAIN global_step=4450 batch=8900
# [E01] TRAIN global_step=4500 batch=9000
# [E01] TRAIN global_step=4550 batch=9100
# [E01] TRAIN global_step=4600 batch=9200
# [E01] TRAIN global_step=4650 batch=9300
# [E01] TRAIN global_step=4700 batch=9400
# [E01] TRAIN global_step=4750 batch=9500
# [E01] TRAIN global_step=4800 batch=9600
# [E01] TRAIN global_step=4850 batch=9700
# [E01] TRAIN global_step=4900 batch=9800
# [E01] TRAIN global_step=4950 batch=9900
# [E01] TRAIN global_step=5000 batch=10000
# [E01] TRAIN global_step=5050 batch=10100
# [E01] TRAIN global_step=5100 batch=10200
# [E01] TRAIN global_step=5150 batch=10300
# [E01] TRAIN global_step=5200 batch=10400
# [E01] TRAIN global_step=5250 batch=10500
# [E01] TRAIN global_step=5300 batch=10600
# [E01] TRAIN global_step=5350 batch=10700
# [E01] TRAIN global_step=5400 batch=10800
# [E01] TRAIN global_step=5450 batch=10900
# [E01] TRAIN global_step=5500 batch=11000
# [E01] TRAIN global_step=5550 batch=11100
# [E01] TRAIN global_step=5600 batch=11200
# [E01] TRAIN global_step=5650 batch=11300
# [E01] TRAIN global_step=5700 batch=11400
# [E01] TRAIN global_step=5750 batch=11500
# [E01] TRAIN global_step=5800 batch=11600
# [E01] TRAIN global_step=5850 batch=11700
# [E01] TRAIN global_step=5900 batch=11800
# [E01] TRAIN global_step=5950 batch=11900
# [E01] TRAIN global_step=6000 batch=12000
# [E01] TRAIN global_step=6050 batch=12100
# [E01] TRAIN global_step=6100 batch=12200
# [E01] TRAIN global_step=6150 batch=12300
# [E01] TRAIN global_step=6200 batch=12400
# [E01] TRAIN global_step=6250 batch=12500
# [E01] TRAIN global_step=6300 batch=12600
# [E01] TRAIN global_step=6350 batch=12700
# [E01] TRAIN global_step=6400 batch=12800
# [E01] TRAIN global_step=6450 batch=12900
# [E01] TRAIN global_step=6500 batch=13000
# [E01] TRAIN global_step=6550 batch=13100
# [E01] TRAIN global_step=6600 batch=13200
# [E01] TRAIN global_step=6650 batch=13300
# [E01] TRAIN global_step=6700 batch=13400
# [E01] TRAIN global_step=6750 batch=13500
# [E01] TRAIN global_step=6800 batch=13600
# [E01] TRAIN global_step=6850 batch=13700
# [E01] TRAIN global_step=6900 batch=13800
# [E01] TRAIN global_step=6950 batch=13900
# [E01] TRAIN global_step=7000 batch=14000
# [E01] TRAIN global_step=7050 batch=14100
# [E01] TRAIN global_step=7100 batch=14200
# [E01] TRAIN global_step=7150 batch=14300
# [E01] TRAIN global_step=7200 batch=14400
# [E01] TRAIN global_step=7250 batch=14500
# [E01] TRAIN global_step=7300 batch=14600
# [E01] TRAIN global_step=7350 batch=14700
# [E01] TRAIN global_step=7400 batch=14800
# [E01] TRAIN global_step=7450 batch=14900
# [E01] TRAIN global_step=7500 batch=15000
# [E01] TRAIN global_step=7550 batch=15100
# [E01] TRAIN global_step=7600 batch=15200
# [E01] TRAIN global_step=7650 batch=15300
# [E01] TRAIN global_step=7700 batch=15400
# [E01] TRAIN global_step=7750 batch=15500
# [E01] TRAIN global_step=7800 batch=15600
# [E01] TRAIN global_step=7850 batch=15700
# [E01] TRAIN global_step=7900 batch=15800
# [E01] TRAIN global_step=7950 batch=15900
# [E01] TRAIN global_step=8000 batch=16000
# [E01] TRAIN global_step=8050 batch=16100
# [E01] TRAIN global_step=8100 batch=16200
# [E01] TRAIN global_step=8150 batch=16300
# [E01] TRAIN global_step=8200 batch=16400
# [E01] TRAIN global_step=8250 batch=16500
# [E01] TRAIN global_step=8300 batch=16600
# [E01] TRAIN global_step=8350 batch=16700
# [E01] TRAIN global_step=8400 batch=16800
# [E01] TRAIN global_step=8450 batch=16900
# [E01] TRAIN global_step=8500 batch=17000
# [E01] TRAIN global_step=8550 batch=17100
# [E01] TRAIN global_step=8600 batch=17200
# [E01] TRAIN global_step=8650 batch=17300
# [E01] TRAIN global_step=8700 batch=17400
# [E01] TRAIN global_step=8750 batch=17500
# [E01] TRAIN global_step=8800 batch=17600
# [E01] TRAIN global_step=8850 batch=17700
# [E01] TRAIN global_step=8900 batch=17800
# [E01] TRAIN global_step=8950 batch=17900
# [E01] TRAIN global_step=9000 batch=18000
# [E01] TRAIN global_step=9050 batch=18100
# [E01] TRAIN global_step=9100 batch=18200
# [E01] TRAIN global_step=9150 batch=18300
# [E01] TRAIN global_step=9200 batch=18400
# [E01] TRAIN global_step=9250 batch=18500
# [E01] TRAIN global_step=9300 batch=18600
# [E01] TRAIN global_step=9350 batch=18700
# [E01] TRAIN global_step=9400 batch=18800
# [E01] TRAIN global_step=9450 batch=18900
# [E01] TRAIN global_step=9500 batch=19000
# [E01] TRAIN global_step=9550 batch=19100
# [E01] TRAIN global_step=9600 batch=19200
# [E01] TRAIN global_step=9650 batch=19300
# [E01] TRAIN global_step=9700 batch=19400
# [E01] TRAIN global_step=9750 batch=19500
# [E01] TRAIN global_step=9800 batch=19600
# [E01] TRAIN global_step=9850 batch=19700
# [E01] TRAIN global_step=9900 batch=19800
# [E01] TRAIN global_step=9950 batch=19900
# [E01] TRAIN global_step=10000 batch=20000
# [E01] TRAIN global_step=10050 batch=20100
# [E01] TRAIN global_step=10100 batch=20200
# [E01] TRAIN global_step=10150 batch=20300
# [E01] TRAIN global_step=10200 batch=20400
# [E01] TRAIN global_step=10250 batch=20500
# [E01] TRAIN global_step=10300 batch=20600
# [E01] TRAIN global_step=10350 batch=20700
# [E01] TRAIN global_step=10400 batch=20800
# [E01] TRAIN global_step=10450 batch=20900
# [E01] TRAIN global_step=10500 batch=21000
# [E01] TRAIN global_step=10550 batch=21100
# [E01] TRAIN global_step=10600 batch=21200
# [E01] TRAIN global_step=10650 batch=21300
# [E01] TRAIN global_step=10700 batch=21400
# [E01] TRAIN global_step=10750 batch=21500
# [E01] TRAIN global_step=10800 batch=21600
# [E01] TRAIN global_step=10850 batch=21700
# [E01] TRAIN global_step=10900 batch=21800
# [E01] TRAIN global_step=10950 batch=21900
# [E01] TRAIN global_step=11000 batch=22000
# [E01] TRAIN global_step=11050 batch=22100
# [E01] TRAIN global_step=11100 batch=22200
# [E01] TRAIN global_step=11150 batch=22300
# [E01] TRAIN global_step=11200 batch=22400
# [E01] TRAIN global_step=11250 batch=22500
# [E01] TRAIN global_step=11300 batch=22600
# [E01] TRAIN global_step=11350 batch=22700
# [E01] TRAIN global_step=11400 batch=22800
# [E01] TRAIN global_step=11450 batch=22900
# [E01] TRAIN global_step=11500 batch=23000
# [E01] TRAIN global_step=11550 batch=23100
# [E01] TRAIN global_step=11600 batch=23200
# [E01] TRAIN global_step=11650 batch=23300
# [E01] TRAIN global_step=11700 batch=23400
# [E01] TRAIN global_step=11750 batch=23500
# [E01] TRAIN global_step=11800 batch=23600
# [E01] TRAIN global_step=11850 batch=23700
# [E01] TRAIN global_step=11900 batch=23800
# [E01] TRAIN global_step=11950 batch=23900
# [E01] TRAIN global_step=12000 batch=24000
# [E01] TRAIN global_step=12050 batch=24100
# [E01] TRAIN global_step=12100 batch=24200
# [E01] TRAIN global_step=12150 batch=24300
# [E01] TRAIN global_step=12200 batch=24400
# [E01] TRAIN global_step=12250 batch=24500
# [E01] TRAIN global_step=12300 batch=24600
# [E01] TRAIN global_step=12350 batch=24700
# [E01] TRAIN global_step=12400 batch=24800
# [E01] TRAIN global_step=12450 batch=24900
# [E01] TRAIN global_step=12500 batch=25000
# [E01] TRAIN global_step=12550 batch=25100
# [E01] TRAIN global_step=12600 batch=25200
# [E01] TRAIN global_step=12650 batch=25300
# [E01] TRAIN global_step=12700 batch=25400
# [E01] TRAIN global_step=12750 batch=25500
# [E01] TRAIN global_step=12800 batch=25600
# [E01] TRAIN global_step=12850 batch=25700
# [E01] TRAIN global_step=12900 batch=25800
# [E01] TRAIN global_step=12950 batch=25900
# [E01] TRAIN global_step=13000 batch=26000
# [E01] TRAIN global_step=13050 batch=26100
# [E01] TRAIN global_step=13100 batch=26200
# [E01] TRAIN global_step=13150 batch=26300
# [E01] TRAIN global_step=13200 batch=26400
# [E01] TRAIN global_step=13250 batch=26500
# [E01] TRAIN global_step=13300 batch=26600
# [E01] TRAIN global_step=13350 batch=26700
# [E01] TRAIN global_step=13400 batch=26800
# [E01] TRAIN global_step=13450 batch=26900
# [E01] TRAIN global_step=13500 batch=27000
# [E01] TRAIN global_step=13550 batch=27100
# [E01] TRAIN global_step=13600 batch=27200
# [E01] TRAIN global_step=13650 batch=27300
# [E01] TRAIN global_step=13700 batch=27400
# [E01] TRAIN global_step=13750 batch=27500
# [E01] TRAIN global_step=13800 batch=27600
# [E01] TRAIN global_step=13850 batch=27700
# [E01] TRAIN global_step=13900 batch=27800
# [E01] TRAIN global_step=13950 batch=27900
# [E01] TRAIN global_step=14000 batch=28000
# [E01] TRAIN loss=4.9667 otu=3.8263 tax=1.1404 tree=0.0000 acc_tax_deep=0.597 (n_deep=14243)
# [E01] VAL loss=8.7827 otu=5.7799 tax=3.0029 tree=0.0000 acc_tax_deep=0.455 (n_deep=315218)
# [E01] ✅ Saved BEST
# [E02] TRAIN global_step=14050 batch=34
# [E02] TRAIN global_step=14100 batch=134
# [E02] TRAIN global_step=14150 batch=234
# [E02] TRAIN global_step=14200 batch=334
# [E02] TRAIN global_step=14250 batch=434
# [E02] TRAIN global_step=14300 batch=534
# [E02] TRAIN global_step=14350 batch=634
# [E02] TRAIN global_step=14400 batch=734
# [E02] TRAIN global_step=14450 batch=834
# [E02] TRAIN global_step=14500 batch=934
# [E02] TRAIN global_step=14550 batch=1034
# [E02] TRAIN global_step=14600 batch=1134
# [E02] TRAIN global_step=14650 batch=1234
# [E02] TRAIN global_step=14700 batch=1334
# [E02] TRAIN global_step=14750 batch=1434
# [E02] TRAIN global_step=14800 batch=1534
# [E02] TRAIN global_step=14850 batch=1634
# [E02] TRAIN global_step=14900 batch=1734
# [E02] TRAIN global_step=14950 batch=1834
# [E02] TRAIN global_step=15000 batch=1934
# [E02] TRAIN global_step=15050 batch=2034
# [E02] TRAIN global_step=15100 batch=2134
# [E02] TRAIN global_step=15150 batch=2234
# [E02] TRAIN global_step=15200 batch=2334
# [E02] TRAIN global_step=15250 batch=2434
# [E02] TRAIN global_step=15300 batch=2534
# [E02] TRAIN global_step=15350 batch=2634
# [E02] TRAIN global_step=15400 batch=2734
# [E02] TRAIN global_step=15450 batch=2834
# [E02] TRAIN global_step=15500 batch=2934
# [E02] TRAIN global_step=15550 batch=3034
# [E02] TRAIN global_step=15600 batch=3134
# [E02] TRAIN global_step=15650 batch=3234
# [E02] TRAIN global_step=15700 batch=3334
# [E02] TRAIN global_step=15750 batch=3434
# [E02] TRAIN global_step=15800 batch=3534
# [E02] TRAIN global_step=15850 batch=3634
# [E02] TRAIN global_step=15900 batch=3734
# [E02] TRAIN global_step=15950 batch=3834
# [E02] TRAIN global_step=16000 batch=3934
# [E02] TRAIN global_step=16050 batch=4034
# [E02] TRAIN global_step=16100 batch=4134
# [E02] TRAIN global_step=16150 batch=4234
# [E02] TRAIN global_step=16200 batch=4334
# [E02] TRAIN global_step=16250 batch=4434
# [E02] TRAIN global_step=16300 batch=4534
# [E02] TRAIN global_step=16350 batch=4634
# [E02] TRAIN global_step=16400 batch=4734
# [E02] TRAIN global_step=16450 batch=4834
# [E02] TRAIN global_step=16500 batch=4934
# [E02] TRAIN global_step=16550 batch=5034
# [E02] TRAIN global_step=16600 batch=5134
# [E02] TRAIN global_step=16650 batch=5234
# [E02] TRAIN global_step=16700 batch=5334
# [E02] TRAIN global_step=16750 batch=5434
# [E02] TRAIN global_step=16800 batch=5534
# [E02] TRAIN global_step=16850 batch=5634
# [E02] TRAIN global_step=16900 batch=5734
# [E02] TRAIN global_step=16950 batch=5834
# [E02] TRAIN global_step=17000 batch=5934
# [E02] TRAIN global_step=17050 batch=6034
# [E02] TRAIN global_step=17100 batch=6134
# [E02] TRAIN global_step=17150 batch=6234
# [E02] TRAIN global_step=17200 batch=6334
# [E02] TRAIN global_step=17250 batch=6434
# [E02] TRAIN global_step=17300 batch=6534
# [E02] TRAIN global_step=17350 batch=6634
# [E02] TRAIN global_step=17400 batch=6734
# [E02] TRAIN global_step=17450 batch=6834
# [E02] TRAIN global_step=17500 batch=6934
# [E02] TRAIN global_step=17550 batch=7034
# [E02] TRAIN global_step=17600 batch=7134
# [E02] TRAIN global_step=17650 batch=7234
# [E02] TRAIN global_step=17700 batch=7334
# [E02] TRAIN global_step=17750 batch=7434
# [E02] TRAIN global_step=17800 batch=7534
# [E02] TRAIN global_step=17850 batch=7634
# [E02] TRAIN global_step=17900 batch=7734
# [E02] TRAIN global_step=17950 batch=7834
# [E02] TRAIN global_step=18000 batch=7934
# [E02] TRAIN global_step=18050 batch=8034
# [E02] TRAIN global_step=18100 batch=8134
# [E02] TRAIN global_step=18150 batch=8234
# [E02] TRAIN global_step=18200 batch=8334
# [E02] TRAIN global_step=18250 batch=8434
# [E02] TRAIN global_step=18300 batch=8534
# [E02] TRAIN global_step=18350 batch=8634
# [E02] TRAIN global_step=18400 batch=8734
# [E02] TRAIN global_step=18450 batch=8834
# [E02] TRAIN global_step=18500 batch=8934
# [E02] TRAIN global_step=18550 batch=9034
# [E02] TRAIN global_step=18600 batch=9134
# [E02] TRAIN global_step=18650 batch=9234
# [E02] TRAIN global_step=18700 batch=9334
# [E02] TRAIN global_step=18750 batch=9434
# [E02] TRAIN global_step=18800 batch=9534
# [E02] TRAIN global_step=18850 batch=9634
# [E02] TRAIN global_step=18900 batch=9734
# [E02] TRAIN global_step=18950 batch=9834
# [E02] TRAIN global_step=19000 batch=9934
# [E02] TRAIN global_step=19050 batch=10034
# [E02] TRAIN global_step=19100 batch=10134
# [E02] TRAIN global_step=19150 batch=10234
# [E02] TRAIN global_step=19200 batch=10334
# [E02] TRAIN global_step=19250 batch=10434
# [E02] TRAIN global_step=19300 batch=10534
# [E02] TRAIN global_step=19350 batch=10634
# [E02] TRAIN global_step=19400 batch=10734
# [E02] TRAIN global_step=19450 batch=10834
# [E02] TRAIN global_step=19500 batch=10934
# [E02] TRAIN global_step=19550 batch=11034
# [E02] TRAIN global_step=19600 batch=11134
# [E02] TRAIN global_step=19650 batch=11234
# [E02] TRAIN global_step=19700 batch=11334
# [E02] TRAIN global_step=19750 batch=11434
# [E02] TRAIN global_step=19800 batch=11534
# [E02] TRAIN global_step=19850 batch=11634
# [E02] TRAIN global_step=19900 batch=11734
# [E02] TRAIN global_step=19950 batch=11834
# [E02] TRAIN global_step=20000 batch=11934
# [E02] TRAIN global_step=20050 batch=12034
# [E02] TRAIN global_step=20100 batch=12134
# [E02] TRAIN global_step=20150 batch=12234
# [E02] TRAIN global_step=20200 batch=12334
# [E02] TRAIN global_step=20250 batch=12434
# [E02] TRAIN global_step=20300 batch=12534
# [E02] TRAIN global_step=20350 batch=12634
# [E02] TRAIN global_step=20400 batch=12734
# [E02] TRAIN global_step=20450 batch=12834
# [E02] TRAIN global_step=20500 batch=12934
# [E02] TRAIN global_step=20550 batch=13034
# [E02] TRAIN global_step=20600 batch=13134
# [E02] TRAIN global_step=20650 batch=13234
# [E02] TRAIN global_step=20700 batch=13334
# [E02] TRAIN global_step=20750 batch=13434
# [E02] TRAIN global_step=20800 batch=13534
# [E02] TRAIN global_step=20850 batch=13634
# [E02] TRAIN global_step=20900 batch=13734
# [E02] TRAIN global_step=20950 batch=13834
# [E02] TRAIN global_step=21000 batch=13934
# [E02] TRAIN global_step=21050 batch=14034
# [E02] TRAIN global_step=21100 batch=14134
# [E02] TRAIN global_step=21150 batch=14234
# [E02] TRAIN global_step=21200 batch=14334
# [E02] TRAIN global_step=21250 batch=14434
# [E02] TRAIN global_step=21300 batch=14534
# [E02] TRAIN global_step=21350 batch=14634
# [E02] TRAIN global_step=21400 batch=14734
# [E02] TRAIN global_step=21450 batch=14834
# [E02] TRAIN global_step=21500 batch=14934
# [E02] TRAIN global_step=21550 batch=15034
# [E02] TRAIN global_step=21600 batch=15134
# [E02] TRAIN global_step=21650 batch=15234
# [E02] TRAIN global_step=21700 batch=15334
# [E02] TRAIN global_step=21750 batch=15434
# [E02] TRAIN global_step=21800 batch=15534
# [E02] TRAIN global_step=21850 batch=15634
# [E02] TRAIN global_step=21900 batch=15734
# [E02] TRAIN global_step=21950 batch=15834
# [E02] TRAIN global_step=22000 batch=15934
# [E02] TRAIN global_step=22050 batch=16034
# [E02] TRAIN global_step=22100 batch=16134
# [E02] TRAIN global_step=22150 batch=16234
# [E02] TRAIN global_step=22200 batch=16334
# [E02] TRAIN global_step=22250 batch=16434
# [E02] TRAIN global_step=22300 batch=16534
# [E02] TRAIN global_step=22350 batch=16634
# [E02] TRAIN global_step=22400 batch=16734
# [E02] TRAIN global_step=22450 batch=16834
# [E02] TRAIN global_step=22500 batch=16934
# [E02] TRAIN global_step=22550 batch=17034
# [E02] TRAIN global_step=22600 batch=17134
# [E02] TRAIN global_step=22650 batch=17234
# [E02] TRAIN global_step=22700 batch=17334
# [E02] TRAIN global_step=22750 batch=17434
# [E02] TRAIN global_step=22800 batch=17534
# [E02] TRAIN global_step=22850 batch=17634
# [E02] TRAIN global_step=22900 batch=17734
# [E02] TRAIN global_step=22950 batch=17834
# [E02] TRAIN global_step=23000 batch=17934
# [E02] TRAIN global_step=23050 batch=18034
# [E02] TRAIN global_step=23100 batch=18134
# [E02] TRAIN global_step=23150 batch=18234
# [E02] TRAIN global_step=23200 batch=18334
# [E02] TRAIN global_step=23250 batch=18434
# [E02] TRAIN global_step=23300 batch=18534
# [E02] TRAIN global_step=23350 batch=18634
# [E02] TRAIN global_step=23400 batch=18734
# [E02] TRAIN global_step=23450 batch=18834
# [E02] TRAIN global_step=23500 batch=18934
# [E02] TRAIN global_step=23550 batch=19034
# [E02] TRAIN global_step=23600 batch=19134
# [E02] TRAIN global_step=23650 batch=19234
# [E02] TRAIN global_step=23700 batch=19334
# [E02] TRAIN global_step=23750 batch=19434
# [E02] TRAIN global_step=23800 batch=19534
# [E02] TRAIN global_step=23850 batch=19634
# [E02] TRAIN global_step=23900 batch=19734
# [E02] TRAIN global_step=23950 batch=19834
# [E02] TRAIN global_step=24000 batch=19934
# [E02] TRAIN global_step=24050 batch=20034
# [E02] TRAIN global_step=24100 batch=20134
# [E02] TRAIN global_step=24150 batch=20234
# [E02] TRAIN global_step=24200 batch=20334
# [E02] TRAIN global_step=24250 batch=20434
# [E02] TRAIN global_step=24300 batch=20534
# [E02] TRAIN global_step=24350 batch=20634
# [E02] TRAIN global_step=24400 batch=20734
# [E02] TRAIN global_step=24450 batch=20834
# [E02] TRAIN global_step=24500 batch=20934
# [E02] TRAIN global_step=24550 batch=21034
# [E02] TRAIN global_step=24600 batch=21134
# [E02] TRAIN global_step=24650 batch=21234
# [E02] TRAIN global_step=24700 batch=21334
# [E02] TRAIN global_step=24750 batch=21434
# [E02] TRAIN global_step=24800 batch=21534
# [E02] TRAIN global_step=24850 batch=21634
# [E02] TRAIN global_step=24900 batch=21734
# [E02] TRAIN global_step=24950 batch=21834
# [E02] TRAIN global_step=25000 batch=21934
# [E02] TRAIN global_step=25050 batch=22034
# [E02] TRAIN global_step=25100 batch=22134
# [E02] TRAIN global_step=25150 batch=22234
# [E02] TRAIN global_step=25200 batch=22334
# [E02] TRAIN global_step=25250 batch=22434
# [E02] TRAIN global_step=25300 batch=22534
# [E02] TRAIN global_step=25350 batch=22634
# [E02] TRAIN global_step=25400 batch=22734
# [E02] TRAIN global_step=25450 batch=22834
# [E02] TRAIN global_step=25500 batch=22934
# [E02] TRAIN global_step=25550 batch=23034
# [E02] TRAIN global_step=25600 batch=23134
# [E02] TRAIN global_step=25650 batch=23234
# [E02] TRAIN global_step=25700 batch=23334
# [E02] TRAIN global_step=25750 batch=23434
# [E02] TRAIN global_step=25800 batch=23534
# [E02] TRAIN global_step=25850 batch=23634
# [E02] TRAIN global_step=25900 batch=23734
# [E02] TRAIN global_step=25950 batch=23834
# [E02] TRAIN global_step=26000 batch=23934
# [E02] TRAIN global_step=26050 batch=24034
# [E02] TRAIN global_step=26100 batch=24134
# [E02] TRAIN global_step=26150 batch=24234
# [E02] TRAIN global_step=26200 batch=24334
# [E02] TRAIN global_step=26250 batch=24434
# [E02] TRAIN global_step=26300 batch=24534
# [E02] TRAIN global_step=26350 batch=24634
# [E02] TRAIN global_step=26400 batch=24734
# [E02] TRAIN global_step=26450 batch=24834
# [E02] TRAIN global_step=26500 batch=24934
# [E02] TRAIN global_step=26550 batch=25034
# [E02] TRAIN global_step=26600 batch=25134
# [E02] TRAIN global_step=26650 batch=25234
# [E02] TRAIN global_step=26700 batch=25334
# [E02] TRAIN global_step=26750 batch=25434
# [E02] TRAIN global_step=26800 batch=25534
# [E02] TRAIN global_step=26850 batch=25634
# [E02] TRAIN global_step=26900 batch=25734
# [E02] TRAIN global_step=26950 batch=25834
# [E02] TRAIN global_step=27000 batch=25934
# [E02] TRAIN global_step=27050 batch=26034
# [E02] TRAIN global_step=27100 batch=26134
# [E02] TRAIN global_step=27150 batch=26234
# [E02] TRAIN global_step=27200 batch=26334
# [E02] TRAIN global_step=27250 batch=26434
# [E02] TRAIN global_step=27300 batch=26534
# [E02] TRAIN global_step=27350 batch=26634
# [E02] TRAIN global_step=27400 batch=26734
# [E02] TRAIN global_step=27450 batch=26834
# [E02] TRAIN global_step=27500 batch=26934
# [E02] TRAIN global_step=27550 batch=27034
# [E02] TRAIN global_step=27600 batch=27134
# [E02] TRAIN global_step=27650 batch=27234
# [E02] TRAIN global_step=27700 batch=27334
# [E02] TRAIN global_step=27750 batch=27434
# [E02] TRAIN global_step=27800 batch=27534
# [E02] TRAIN global_step=27850 batch=27634
# [E02] TRAIN global_step=27900 batch=27734
# [E02] TRAIN global_step=27950 batch=27834
# [E02] TRAIN global_step=28000 batch=27934
# [E02] TRAIN global_step=28050 batch=28034
# [E02] TRAIN loss=3.6272 otu=2.8820 tax=0.7452 tree=0.0000 acc_tax_deep=0.840 (n_deep=14662)
# [E02] VAL loss=8.2087 otu=5.3483 tax=2.8604 tree=0.0000 acc_tax_deep=0.482 (n_deep=315218)
# [E02] ✅ Saved BEST
# [E03] TRAIN global_step=28100 batch=68
# [E03] TRAIN global_step=38100 batch=20068
# [E03] TRAIN global_step=38150 batch=20168
# [E03] TRAIN global_step=38200 batch=20268
# [E03] TRAIN global_step=38250 batch=20368
# [E03] TRAIN global_step=38300 batch=20468
# [E03] TRAIN global_step=38350 batch=20568
# [E03] TRAIN global_step=38400 batch=20668
# [E03] TRAIN global_step=38450 batch=20768
# [E03] TRAIN global_step=38500 batch=20868
# [E03] TRAIN global_step=38550 batch=20968
# [E03] TRAIN global_step=38600 batch=21068
# [E03] TRAIN global_step=38650 batch=21168
# [E03] TRAIN global_step=38700 batch=21268
# [E03] TRAIN global_step=38750 batch=21368
# [E03] TRAIN global_step=38800 batch=21468
# [E03] TRAIN global_step=38850 batch=21568
# [E03] TRAIN global_step=38900 batch=21668
# [E03] TRAIN global_step=38950 batch=21768
# [E03] TRAIN global_step=39000 batch=21868
# [E03] TRAIN global_step=39050 batch=21968
# [E03] TRAIN global_step=39100 batch=22068
# [E03] TRAIN global_step=39150 batch=22168
# [E03] TRAIN global_step=39200 batch=22268
# [E03] TRAIN global_step=39250 batch=22368
# [E03] TRAIN global_step=39300 batch=22468
# [E03] TRAIN global_step=39350 batch=22568
# [E03] TRAIN global_step=39400 batch=22668
# [E03] TRAIN global_step=39450 batch=22768
# [E03] TRAIN global_step=39500 batch=22868
# [E03] TRAIN global_step=39550 batch=22968
# [E03] TRAIN global_step=39600 batch=23068
# [E03] TRAIN global_step=39650 batch=23168
# [E03] TRAIN global_step=39700 batch=23268
# [E03] TRAIN global_step=39750 batch=23368
# [E03] TRAIN global_step=39800 batch=23468
# [E03] TRAIN global_step=39850 batch=23568
# [E03] TRAIN global_step=39900 batch=23668
# [E03] TRAIN global_step=39950 batch=23768
# [E03] TRAIN global_step=40000 batch=23868
# [E03] TRAIN global_step=40050 batch=23968
# [E03] TRAIN global_step=40100 batch=24068
# [E03] TRAIN global_step=40150 batch=24168
# [E03] TRAIN global_step=40200 batch=24268
# [E03] TRAIN global_step=40250 batch=24368
# [E03] TRAIN global_step=40300 batch=24468
# [E03] TRAIN global_step=40350 batch=24568
# [E03] TRAIN global_step=40400 batch=24668
# [E03] TRAIN global_step=40450 batch=24768
# [E03] TRAIN global_step=40500 batch=24868
# [E03] TRAIN global_step=40550 batch=24968
# [E03] TRAIN global_step=40600 batch=25068
# [E03] TRAIN global_step=40650 batch=25168
# [E03] TRAIN global_step=40700 batch=25268
# [E03] TRAIN global_step=40750 batch=25368
# [E03] TRAIN global_step=40800 batch=25468
# [E03] TRAIN global_step=40850 batch=25568
# [E03] TRAIN global_step=40900 batch=25668
# [E03] TRAIN global_step=40950 batch=25768
# [E03] TRAIN global_step=41000 batch=25868
# [E03] TRAIN global_step=41050 batch=25968
# [E03] TRAIN global_step=41100 batch=26068
# [E03] TRAIN global_step=41150 batch=26168
# [E03] TRAIN global_step=41200 batch=26268
# [E03] TRAIN global_step=41250 batch=26368
# [E03] TRAIN global_step=41300 batch=26468
# [E03] TRAIN global_step=41350 batch=26568
# [E03] TRAIN global_step=41400 batch=26668
# [E03] TRAIN global_step=41450 batch=26768
# [E03] TRAIN global_step=41500 batch=26868
# [E03] TRAIN global_step=41550 batch=26968
# [E03] TRAIN global_step=41600 batch=27068
# [E03] TRAIN global_step=41650 batch=27168
# [E03] TRAIN global_step=41700 batch=27268
# [E03] TRAIN global_step=41750 batch=27368
# [E03] TRAIN global_step=41800 batch=27468
# [E03] TRAIN global_step=41850 batch=27568
# [E03] TRAIN global_step=41900 batch=27668
# [E03] TRAIN global_step=41950 batch=27768
# [E03] TRAIN global_step=42000 batch=27868
# [E03] TRAIN global_step=42050 batch=27968
# [E03] TRAIN loss=3.8562 otu=3.3187 tax=0.5376 tree=0.0000 acc_tax_deep=0.718 (n_deep=13924)
# [E03] VAL loss=8.0571 otu=5.2229 tax=2.8342 tree=0.0000 acc_tax_deep=0.487 (n_deep=315218)
# [E03] ✅ Saved BEST
# [E04] TRAIN global_step=42100 batch=2
# [E04] TRAIN global_step=42150 batch=102
# [E04] TRAIN global_step=42200 batch=202
# [E04] TRAIN global_step=42250 batch=302
# [E04] TRAIN global_step=42300 batch=402
# [E04] TRAIN global_step=42350 batch=502
# [E04] TRAIN global_step=42400 batch=602
# [E04] TRAIN global_step=42450 batch=702
# [E04] TRAIN global_step=42500 batch=802
# [E04] TRAIN global_step=42550 batch=902
# [E04] TRAIN global_step=42600 batch=1002
# [E04] TRAIN global_step=42650 batch=1102
# [E04] TRAIN global_step=42700 batch=1202
# [E04] TRAIN global_step=42750 batch=1302
# [E04] TRAIN global_step=42800 batch=1402
# [E04] TRAIN global_step=42850 batch=1502
# [E04] TRAIN global_step=42900 batch=1602
# [E04] TRAIN global_step=42950 batch=1702
# [E04] TRAIN global_step=43000 batch=1802
# [E04] TRAIN global_step=43050 batch=1902
# [E04] TRAIN global_step=43100 batch=2002
# [E04] TRAIN global_step=43150 batch=2102
# [E04] TRAIN global_step=43200 batch=2202
# [E04] TRAIN global_step=43250 batch=2302
# [E04] TRAIN global_step=43300 batch=2402
# [E04] TRAIN global_step=43350 batch=2502
# [E04] TRAIN global_step=43400 batch=2602
# [E04] TRAIN global_step=43450 batch=2702
# [E04] TRAIN global_step=43500 batch=2802
# [E04] TRAIN global_step=43550 batch=2902
# [E04] TRAIN global_step=43600 batch=3002
# [E04] TRAIN global_step=43650 batch=3102
# [E04] TRAIN global_step=43700 batch=3202
# [E04] TRAIN global_step=43750 batch=3302
# [E04] TRAIN global_step=43800 batch=3402
# [E04] TRAIN global_step=43850 batch=3502
# [E04] TRAIN global_step=43900 batch=3602
# [E04] TRAIN global_step=43950 batch=3702
# [E04] TRAIN global_step=44000 batch=3802
# [E04] TRAIN global_step=44050 batch=3902
# [E04] TRAIN global_step=44100 batch=4002
# [E04] TRAIN global_step=44150 batch=4102
# [E04] TRAIN global_step=44200 batch=4202
# [E04] TRAIN global_step=44250 batch=4302
# [E04] TRAIN global_step=44300 batch=4402
# [E04] TRAIN global_step=44350 batch=4502
# [E04] TRAIN global_step=47700 batch=11202
# [E04] TRAIN global_step=47750 batch=11302
# [E04] TRAIN global_step=47800 batch=11402
# [E04] TRAIN global_step=47850 batch=11502
# [E04] TRAIN global_step=47900 batch=11602
# [E04] TRAIN global_step=47950 batch=11702
# [E04] TRAIN global_step=48000 batch=11802
# [E04] TRAIN global_step=48050 batch=11902
# [E04] TRAIN global_step=48100 batch=12002
# [E04] TRAIN global_step=48150 batch=12102
# [E04] TRAIN global_step=48200 batch=12202
# [E04] TRAIN global_step=48250 batch=12302
# [E04] TRAIN global_step=48300 batch=12402
# [E04] TRAIN global_step=48350 batch=12502
# [E04] TRAIN global_step=48400 batch=12602
# [E04] TRAIN global_step=48450 batch=12702
# [E04] TRAIN global_step=48500 batch=12802
# [E04] TRAIN global_step=48550 batch=12902
# [E04] TRAIN global_step=48600 batch=13002
# [E04] TRAIN global_step=48650 batch=13102
# [E04] TRAIN global_step=48700 batch=13202
# [E04] TRAIN global_step=48750 batch=13302
# [E04] TRAIN global_step=48800 batch=13402
# [E04] TRAIN global_step=48850 batch=13502
# [E04] TRAIN global_step=48900 batch=13602
# [E04] TRAIN global_step=48950 batch=13702
# [E04] TRAIN global_step=49000 batch=13802
# [E04] TRAIN global_step=49050 batch=13902
# [E04] TRAIN global_step=49100 batch=14002
# [E04] TRAIN global_step=49150 batch=14102
# [E04] TRAIN global_step=49200 batch=14202
# [E04] TRAIN global_step=49250 batch=14302
# [E04] TRAIN global_step=49300 batch=14402
# [E04] TRAIN global_step=49350 batch=14502
# [E04] TRAIN global_step=49400 batch=14602
# [E04] TRAIN global_step=49450 batch=14702
# [E04] TRAIN global_step=49500 batch=14802
# [E04] TRAIN global_step=49550 batch=14902
# [E04] TRAIN global_step=49600 batch=15002
# [E04] TRAIN global_step=49650 batch=15102
# [E04] TRAIN global_step=49700 batch=15202
# [E04] TRAIN global_step=49750 batch=15302
# [E04] TRAIN global_step=49800 batch=15402
# [E04] TRAIN global_step=49850 batch=15502
# [E04] TRAIN global_step=49900 batch=15602
# [E04] TRAIN global_step=49950 batch=15702
# [E04] TRAIN global_step=50000 batch=15802
# [E04] TRAIN global_step=50050 batch=15902
# [E04] TRAIN global_step=50100 batch=16002
# [E04] TRAIN global_step=50150 batch=16102
# [E04] TRAIN global_step=50200 batch=16202
# [E04] TRAIN global_step=50250 batch=16302
# [E04] TRAIN global_step=50300 batch=16402
# [E04] TRAIN global_step=50350 batch=16502
# [E04] TRAIN global_step=50400 batch=16602
# [E04] TRAIN global_step=50450 batch=16702
# [E04] TRAIN global_step=50500 batch=16802
# [E04] TRAIN global_step=50550 batch=16902
# [E04] TRAIN global_step=50600 batch=17002
# [E04] TRAIN global_step=50650 batch=17102
# [E04] TRAIN global_step=50700 batch=17202
# [E04] TRAIN global_step=50750 batch=17302
# [E04] TRAIN global_step=50800 batch=17402
# [E04] TRAIN global_step=50850 batch=17502
# [E04] TRAIN global_step=50900 batch=17602
# [E04] TRAIN global_step=50950 batch=17702
# [E04] TRAIN global_step=51000 batch=17802
# [E24] TRAIN global_step=326450 batch=7382
# [E24] TRAIN global_step=326500 batch=7482
# [E24] TRAIN global_step=326550 batch=7582
# [E24] TRAIN global_step=326600 batch=7682
# [E24] TRAIN global_step=326650 batch=7782
# [E24] TRAIN global_step=326700 batch=7882
# [E24] TRAIN global_step=326750 batch=7982
# [E24] TRAIN global_step=326800 batch=8082
# [E24] TRAIN global_step=326850 batch=8182
# [E24] TRAIN global_step=326900 batch=8282
# [E24] TRAIN global_step=326950 batch=8382
# [E24] TRAIN global_step=327000 batch=8482
# [E24] TRAIN global_step=327050 batch=8582
# [E24] TRAIN global_step=327100 batch=8682
# [E24] TRAIN global_step=327150 batch=8782
# [E24] TRAIN global_step=327200 batch=8882
# [E24] TRAIN global_step=327250 batch=8982
# [E24] TRAIN global_step=327300 batch=9082
# [E24] TRAIN global_step=327350 batch=9182
# [E24] TRAIN global_step=327400 batch=9282
# [E24] TRAIN global_step=327450 batch=9382
# [E24] TRAIN global_step=327500 batch=9482
# [E24] TRAIN global_step=327550 batch=9582
# [E24] TRAIN global_step=327600 batch=9682
# [E24] TRAIN global_step=327650 batch=9782
# [E24] TRAIN global_step=327700 batch=9882
# [E24] TRAIN global_step=327750 batch=9982
# [E24] TRAIN global_step=327800 batch=10082
# [E24] TRAIN global_step=327850 batch=10182
# [E24] TRAIN global_step=327900 batch=10282
# [E24] TRAIN global_step=327950 batch=10382
# [E24] TRAIN global_step=328000 batch=10482
# [E24] TRAIN global_step=328050 batch=10582
# [E24] TRAIN global_step=328100 batch=10682
# [E24] TRAIN global_step=328150 batch=10782
# [E24] TRAIN global_step=328200 batch=10882
# [E24] TRAIN global_step=328250 batch=10982
# [E24] TRAIN global_step=328300 batch=11082
# [E24] TRAIN global_step=328350 batch=11182
# [E24] TRAIN global_step=328400 batch=11282
# [E24] TRAIN global_step=328450 batch=11382
# [E24] TRAIN global_step=328500 batch=11482
# [E24] TRAIN global_step=328550 batch=11582
# [E24] TRAIN global_step=328600 batch=11682
# [E24] TRAIN global_step=328650 batch=11782
# [E24] TRAIN global_step=328700 batch=11882
# [E24] TRAIN global_step=328750 batch=11982
# [E24] TRAIN global_step=328800 batch=12082
# [E24] TRAIN global_step=328850 batch=12182
# [E24] TRAIN global_step=328900 batch=12282
# [E24] TRAIN global_step=328950 batch=12382
# [E24] TRAIN global_step=329000 batch=12482
# [E24] TRAIN global_step=329050 batch=12582
# [E24] TRAIN global_step=329100 batch=12682
# [E24] TRAIN global_step=329150 batch=12782
# [E24] TRAIN global_step=329200 batch=12882
# [E24] TRAIN global_step=329250 batch=12982
# [E24] TRAIN global_step=329300 batch=13082
# [E24] TRAIN global_step=329350 batch=13182
# [E24] TRAIN global_step=329400 batch=13282
# [E24] TRAIN global_step=329450 batch=13382
# [E24] TRAIN global_step=329500 batch=13482
# [E24] TRAIN global_step=329550 batch=13582
# [E24] TRAIN global_step=329600 batch=13682
# [E24] TRAIN global_step=329650 batch=13782
# [E24] TRAIN global_step=329700 batch=13882
# [E24] TRAIN global_step=329750 batch=13982
# [E24] TRAIN global_step=329800 batch=14082
# [E24] TRAIN global_step=329850 batch=14182
# [E24] TRAIN global_step=329900 batch=14282
# [E24] TRAIN global_step=329950 batch=14382
# [E24] TRAIN global_step=330000 batch=14482
# [E24] TRAIN global_step=330050 batch=14582
# [E24] TRAIN global_step=330100 batch=14682
# [E24] TRAIN global_step=330150 batch=14782
# [E24] TRAIN global_step=330200 batch=14882
# [E24] TRAIN global_step=330250 batch=14982
# [E24] TRAIN global_step=330300 batch=15082
# [E24] TRAIN global_step=330350 batch=15182
# [E24] TRAIN global_step=330400 batch=15282
# [E24] TRAIN global_step=330450 batch=15382
# [E24] TRAIN global_step=330500 batch=15482
# [E24] TRAIN global_step=330550 batch=15582
# [E24] TRAIN global_step=330600 batch=15682
# [E24] TRAIN global_step=330650 batch=15782
# [E24] TRAIN global_step=330700 batch=15882
# [E24] TRAIN global_step=330750 batch=15982
# [E24] TRAIN global_step=330800 batch=16082
# [E24] TRAIN global_step=330850 batch=16182
# [E24] TRAIN global_step=330900 batch=16282
# [E24] TRAIN global_step=330950 batch=16382
# [E24] TRAIN global_step=331000 batch=16482
# [E24] TRAIN global_step=331050 batch=16582
# [E24] TRAIN global_step=331100 batch=16682
# [E24] TRAIN global_step=331150 batch=16782
# [E24] TRAIN global_step=331200 batch=16882
# [E24] TRAIN global_step=331250 batch=16982
# [E24] TRAIN global_step=331300 batch=17082
# [E24] TRAIN global_step=331350 batch=17182
# [E24] TRAIN global_step=331400 batch=17282
# [E24] TRAIN global_step=331450 batch=17382
# [E24] TRAIN global_step=331500 batch=17482
# [E24] TRAIN global_step=331550 batch=17582
# [E24] TRAIN global_step=331600 batch=17682
# [E24] TRAIN global_step=331650 batch=17782
# [E24] TRAIN global_step=331700 batch=17882
# [E24] TRAIN global_step=331750 batch=17982
# [E24] TRAIN global_step=331800 batch=18082
# [E24] TRAIN global_step=331850 batch=18182
# [E24] TRAIN global_step=331900 batch=18282
# [E24] TRAIN global_step=331950 batch=18382
# [E24] TRAIN global_step=332000 batch=18482
# [E24] TRAIN global_step=332050 batch=18582
# [E24] TRAIN global_step=332100 batch=18682
# [E24] TRAIN global_step=332150 batch=18782
# [E24] TRAIN global_step=332200 batch=18882
# [E24] TRAIN global_step=332250 batch=18982
# [E24] TRAIN global_step=332300 batch=19082
# [E24] TRAIN global_step=332350 batch=19182
# [E24] TRAIN global_step=332400 batch=19282
# [E24] TRAIN global_step=332450 batch=19382
# [E24] TRAIN global_step=332500 batch=19482
# [E24] TRAIN global_step=332550 batch=19582
# [E24] TRAIN global_step=332600 batch=19682
# [E24] TRAIN global_step=332650 batch=19782
# [E24] TRAIN global_step=332700 batch=19882
# [E24] TRAIN global_step=332750 batch=19982
# [E24] TRAIN global_step=332800 batch=20082
# [E24] TRAIN global_step=332850 batch=20182
# [E24] TRAIN global_step=332900 batch=20282
# [E24] TRAIN global_step=332950 batch=20382
# [E24] TRAIN global_step=333000 batch=20482
# [E24] TRAIN global_step=333050 batch=20582
# [E24] TRAIN global_step=333100 batch=20682
# [E24] TRAIN global_step=333150 batch=20782
# [E24] TRAIN global_step=333200 batch=20882
# [E24] TRAIN global_step=333250 batch=20982
# [E24] TRAIN global_step=333300 batch=21082
# [E24] TRAIN global_step=333350 batch=21182
# [E24] TRAIN global_step=333400 batch=21282
# [E24] TRAIN global_step=333450 batch=21382
# [E24] TRAIN global_step=333500 batch=21482
# [E24] TRAIN global_step=333550 batch=21582
# [E24] TRAIN global_step=333600 batch=21682
# [E24] TRAIN global_step=333650 batch=21782
# [E24] TRAIN global_step=333700 batch=21882
# [E24] TRAIN global_step=333750 batch=21982
# [E24] TRAIN global_step=333800 batch=22082
# [E24] TRAIN global_step=333850 batch=22182
# [E24] TRAIN global_step=333900 batch=22282
# [E24] TRAIN global_step=333950 batch=22382
# [E24] TRAIN global_step=334000 batch=22482
# [E24] TRAIN global_step=334050 batch=22582
# [E24] TRAIN global_step=334100 batch=22682
# [E24] TRAIN global_step=334150 batch=22782
# [E24] TRAIN global_step=334200 batch=22882
# [E24] TRAIN global_step=334250 batch=22982
# [E24] TRAIN global_step=334300 batch=23082
# [E24] TRAIN global_step=334350 batch=23182
# [E24] TRAIN global_step=334400 batch=23282
# [E24] TRAIN global_step=334450 batch=23382
# [E24] TRAIN global_step=334500 batch=23482
# [E24] TRAIN global_step=334550 batch=23582
# [E24] TRAIN global_step=334600 batch=23682
# [E24] TRAIN global_step=334650 batch=23782
# [E24] TRAIN global_step=334700 batch=23882
# [E24] TRAIN global_step=334750 batch=23982
# [E24] TRAIN global_step=334800 batch=24082
# [E24] TRAIN global_step=334850 batch=24182
# [E24] TRAIN global_step=334900 batch=24282
# [E24] TRAIN global_step=334950 batch=24382
# [E24] TRAIN global_step=335000 batch=24482
# [E24] TRAIN global_step=335050 batch=24582
# [E24] TRAIN global_step=335100 batch=24682
# [E24] TRAIN global_step=335150 batch=24782
# [E24] TRAIN global_step=335200 batch=24882
# [E24] TRAIN global_step=335250 batch=24982
# [E24] TRAIN global_step=335300 batch=25082
# [E24] TRAIN global_step=335350 batch=25182
# [E24] TRAIN global_step=335400 batch=25282
# [E24] TRAIN global_step=335450 batch=25382
# [E24] TRAIN global_step=335500 batch=25482
# [E24] TRAIN global_step=335550 batch=25582
# [E24] TRAIN global_step=335600 batch=25682
# [E24] TRAIN global_step=335650 batch=25782
# [E24] TRAIN global_step=335700 batch=25882
# [E24] TRAIN global_step=335750 batch=25982
# [E24] TRAIN global_step=335800 batch=26082
# [E24] TRAIN global_step=335850 batch=26182
# [E24] TRAIN global_step=335900 batch=26282
# [E24] TRAIN global_step=335950 batch=26382
# [E24] TRAIN global_step=336000 batch=26482
# [E24] TRAIN global_step=336050 batch=26582
# [E24] TRAIN global_step=336100 batch=26682
# [E24] TRAIN global_step=336150 batch=26782
# [E24] TRAIN global_step=336200 batch=26882
# [E24] TRAIN global_step=336250 batch=26982
# [E24] TRAIN global_step=336300 batch=27082
# [E24] TRAIN global_step=336350 batch=27182
# [E24] TRAIN global_step=336400 batch=27282
# [E24] TRAIN global_step=336450 batch=27382
# [E24] TRAIN global_step=336500 batch=27482
# [E24] TRAIN global_step=336550 batch=27582
# [E24] TRAIN global_step=336600 batch=27682
# [E24] TRAIN global_step=336650 batch=27782
# [E24] TRAIN global_step=336700 batch=27882
# [E24] TRAIN global_step=336750 batch=27982
# [E24] TRAIN loss=2.7640 otu=2.3170 tax=0.4470 tree=0.0000 acc_tax_deep=0.733 (n_deep=14709)
# [E24] VAL loss=7.2884 otu=4.6284 tax=2.6600 tree=0.0000 acc_tax_deep=0.501 (n_deep=315218)

# %%
import json, pandas as pd, matplotlib.pyplot as plt

# ======== CONFIG ========
metrics_path = os.path.join(out_dir, "metrics.jsonl")  # your run folder
# =========================

# --- load and tidy ---
rows = [json.loads(l) for l in open(metrics_path) if l.strip()]
df = pd.DataFrame(rows).sort_values(["epoch", "step"], ignore_index=True)

train_ep = df[df["split"] == "train_epoch"].copy()
val_ep   = df[df["split"] == "val_epoch"].copy()

# --- colors ---
c_total, c_otu, c_tax, c_tree = "C3", "C0", "C1", "C2"

fig, ax = plt.subplots(figsize=(10, 5))

# --- total loss ---
if "loss" in train_ep.columns and "loss" in val_ep.columns:
    ax.plot(train_ep["epoch"], train_ep["loss"], "o-",  color=c_total, label="train total")
    ax.plot(val_ep["epoch"],   val_ep["loss"],   "o--", color=c_total, label="val total")

# --- OTU / TAX losses ---
if {"loss_otu","loss_tax"}.issubset(train_ep.columns) and {"loss_otu","loss_tax"}.issubset(val_ep.columns):
    ax.plot(train_ep["epoch"], train_ep["loss_otu"], "s-",  color=c_otu, label="train OTU")
    ax.plot(val_ep["epoch"],   val_ep["loss_otu"],   "s--", color=c_otu, label="val OTU")
    ax.plot(train_ep["epoch"], train_ep["loss_tax"], "^-",  color=c_tax, label="train TAX")
    ax.plot(val_ep["epoch"],   val_ep["loss_tax"],   "^--", color=c_tax, label="val TAX")

# # --- Tree loss (optional) ---
# if "loss_tree" in train_ep.columns and "loss_tree" in val_ep.columns:
#     ax.plot(train_ep["epoch"], 10*train_ep["loss_tree"], "d-",  color=c_tree, label="train TREE")
#     ax.plot(val_ep["epoch"],   10*val_ep["loss_tree"],   "d--", color=c_tree, label="val TREE")

ax.set_xlabel("epoch")
ax.set_ylabel("loss")
ax.set_title("Loss components per epoch")
ax.grid(alpha=0.25)
ax.legend(ncol=4, loc="upper right", frameon=False)
plt.tight_layout()
plt.show()

# %%
train_st = df[df["split"] == "train_step"].copy()
val_st   = df[df["split"] == "val_step"].copy()

fig, ax = plt.subplots(figsize=(10, 5))

if "loss" in train_st.columns:
    ax.plot(train_st["step"], train_st["loss"], "-", label="train total (window)")
if "loss" in val_st.columns:
    ax.plot(val_st["step"], val_st["loss"], "--", label="val total (window)")

ax.set_xlabel("global step")
ax.set_ylabel("loss")
ax.set_title("Loss (windowed logs)")
ax.grid(alpha=0.25)
ax.legend(frameon=False)
plt.tight_layout()
plt.show()
